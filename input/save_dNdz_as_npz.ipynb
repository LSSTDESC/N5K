# %%
import numpy as np

# %%
dNdz_s = np.loadtxt('./dNdz_srcs_LSSTSRD_zb0_sigz0.05.dat')
dNdz_c = np.loadtxt('./dNdz_clust_LSSTSRD_zb0_sigz0.03.dat')

# %%
z_sh = dNdz_s[:,0]
dNdz_sh = dNdz_s[:,1:]

# %%
z_cl = dNdz_c[:,0]
dNdz_cl = dNdz_c[:,1:]

# %%
np.savez('./dNdzs.npz', z_sh=z_sh, dNdz_sh=dNdz_sh, z_cl=z_cl, dNdz_cl=dNdz_cl)

# %%
dNdz_file = np.load('./dNdzs.npz')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
for i in range(0,5):
    plt.plot(dNdz_file['z_sh'], dNdz_file['dNdz_sh'][:,i])
plt.show()

# %%
plt.figure()
for i in range(0,10):
    plt.plot(dNdz_file['z_cl'], dNdz_file['dNdz_cl'][:,i])
plt.show()

# %%
kern_file = np.load('./kernels.npz')

# %%
plt.figure()
for i in range(0,5):
    plt.plot(kern_file['z_sh'], kern_file['kernels_sh'][i])
plt.show()

# %%
plt.figure()
for i in range(0,10):
    plt.plot(kern_file['z_cl'], kern_file['kernels_cl'][i])
plt.show()

# %%
plt.figure()
for i in range(0,5):
    plt.plot(kern_file['chi_sh'], kern_file['kernels_sh'][i])
plt.show()

# %%
plt.figure()
for i in range(0,10):
    plt.plot(kern_file['chi_cl'], kern_file['kernels_cl'][i])
plt.show()
